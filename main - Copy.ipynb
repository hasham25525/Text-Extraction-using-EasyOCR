# %% [markdown]
# # Step 1: Install and import modules

# %%
pip install easyocr
# Out:
# Requirement already satisfied: easyocr in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (1.7.0)
# Requirement already satisfied: torch in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (0.15.2)
# Requirement already satisfied: opencv-python-headless in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (4.7.0.72)
# Requirement already satisfied: scipy in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: numpy in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.24.3)
# Requirement already satisfied: Pillow in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (9.5.0)
# Requirement already satisfied: scikit-image in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (0.21.0)
# Requirement already satisfied: python-bidi in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: Shapely in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (2.0.1)
# Requirement already satisfied: pyclipper in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.3.0.post4)
# Requirement already satisfied: ninja in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.11.1)
# Requirement already satisfied: requests in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from torchvision>=0.5->easyocr) (2.31.0)
# Requirement already satisfied: filelock in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from torch->easyocr) (3.12.0)
# Requirement already satisfied: typing-extensions in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from torch->easyocr) (4.6.3)
# Requirement already satisfied: sympy in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from torch->easyocr) (3.1)
# Requirement already satisfied: jinja2 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: six in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (2.31.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (1.4.1)
# Requirement already satisfied: packaging>=21 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (23.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch->easyocr) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lenovo\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import easyocr
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Step 2: Image loading and text recognition using EasyOCR

# %%
im_1_path = './images/1_tshirt.jpg'
im_2_path = './images/2_tshirt.jpg'
im_3_path = './images/3_tshirt.jpg'
im_4_path = './images/4_tshirt.jpg'

# %% [markdown]
# # Step 3: Overlay recognized text on image using OpenCV

# %%
def overlay_ocr_text(img_path, save_name):
    '''loads an image, recognizes text, and overlays the text on the image.'''
    
    # loads image
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    dpi = 80
    fig_width, fig_height = int(img.shape[0]/dpi), int(img.shape[1]/dpi)
    plt.figure()
    f, axarr = plt.subplots(1,2, figsize=(fig_width, fig_height)) 
    axarr[0].imshow(img)
    
    # recognize text
    result = recognize_text(img_path)

    # if OCR prob is over 0.5, overlay bounding box and text
    for (bbox, text, prob) in result:
        if prob >= 0.5:
            # display 
            print(f'Detected text: {text} (Probability: {prob:.2f})')

            # get top-left and bottom-right bbox vertices
            (top_left, top_right, bottom_right, bottom_left) = bbox
            top_left = (int(top_left[0]), int(top_left[1]))
            bottom_right = (int(bottom_right[0]), int(bottom_right[1]))

            # create a rectangle for bbox display
            cv2.rectangle(img=img, pt1=top_left, pt2=bottom_right, color=(255, 0, 0), thickness=10)

            # put recognized text
            cv2.putText(img=img, text=text, org=(top_left[0], top_left[1] - 10), fontFace=cv2.FONT_HERSHEY_SIMPLEX, fontScale=1, color=(255, 0, 0), thickness=8)
        
    # show and save image
    axarr[1].imshow(img)
    plt.savefig(f'./output/{save_name}_overlay.jpg', bbox_inches='tight')

# %%
overlay_ocr_text(im_1_path, '1_tshirt')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: Graphic (Probability: 0.65)
# Detected text: Designer (Probability: 1.00)

# %%
overlay_ocr_text(im_2_path, '2_tshirt')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: DO (Probability: 0.90179)
# Detected text: WHATEVER (Probability: 0.99438)
# Detected text: TAKES (Probability: 0.99989)

# %%
overlay_ocr_text(im_3_path, '3_tshirt')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: Early (Probability: 0.95181)
# Detected text: Biras (Probability: 0.52912)

# %%
overlay_ocr_text(im_4_path, '4_tshirt')
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Detected text: NOT A (Probability: 0.62276)
# Detected text: Tourist (Probability: 0.57171)
# Detected text: HERE (Probability: 0.95641)
